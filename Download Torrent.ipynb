"udp://tracker1.bt.moack.co.kr:80/announce",
"udp://tracker-udp.gbitt.info:80/announce",
"udp://ts.populargamers.co.za:6969/announce",
"http://tracker.openbittorrent.com:80/announce",
"udp://open.demonii.com:1337/announce",
"udp://tracker.torrent.eu.org:451/announce",
"http://bt.endpot.com:80/announce",
"udp://tracker.tiny-vps.com:6969/announce",
"udp://explodie.org:6969/announce",
"udp://tracker2.dler.org:80/announce",
"udp://tracker.bittor.pw:1337/announce",
"udp://tracker.auctor.tv:6969/announce",
"udp://tracker.4.babico.name.tr:3131/announce"]

# %%
import urllib

New_Magnet_Link = []
for m in Magnet_Link:
    for t in trackers:
        m = m + "&" + urllib.parse.urlencode({"tr":t})
    New_Magnet_Link.append(m)
Magnet_Link = New_Magnet_Link

# %% [markdown]
# **Note:** Magnet links start like **magnet:?xt=urn***

# %% [markdown]
# ### Mount Google Drive - When prompted, give the permissions
# *We are mounting the Google Drive so that the torrent can be downloaded in the Google Drive. Free tier has 15GB storage, so make sure the torrent size is less than the storage you have on drive.*

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# ### Installing Libraries (libtorrent and Initialize Session)

# %%
# !apt install python3-libtorrent
# !python -m pip install --upgrade pip setuptools wheel
# !python -m pip install libtorrent
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libtorrent-rasterbar2.0
# The following NEW packages will be installed:
#   libtorrent-rasterbar2.0 python3-libtorrent
# 0 upgraded, 2 newly installed, 0 to remove and 45 not upgraded.
# Need to get 2,098 kB of archives.
# After this operation, 7,907 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtorrent-rasterbar2.0 amd64 2.0.5-5 [1,501 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-libtorrent amd64 2.0.5-5 [597 kB]
# Fetched 2,098 kB in 1s (1,462 kB/s)
# Selecting previously unselected package libtorrent-rasterbar2.0:amd64.
# (Reading database ... 123594 files and directories currently installed.)
# Preparing to unpack .../libtorrent-rasterbar2.0_2.0.5-5_amd64.deb ...
# Unpacking libtorrent-rasterbar2.0:amd64 (2.0.5-5) ...
# ...

# %%
import libtorrent as lt
ses = lt.session()
ses.listen_on(6881, 6891)
params = {"save_path": "/content"}
downloads = []
for m in Magnet_Link:
    k = lt.add_magnet_uri(ses, m, params)
    k.set_sequential_download(True)
    downloads.append(k)
# Out:
# <ipython-input-3-2fb7fd065834>:3: DeprecationWarning: listen_on() is deprecated
#   ses.listen_on(6881, 6891)
# <ipython-input-3-2fb7fd065834>:7: DeprecationWarning: add_magnet_uri() is deprecated
#   k = lt.add_magnet_uri(ses, m, params)
# <ipython-input-3-2fb7fd065834>:8: DeprecationWarning: set_sequential_download() is deprecated
#   k.set_sequential_download(True)

# %% [markdown]
# ### Start Download

# %%
import time
from IPython.display import display
import ipywidgets as widgets

state_str = [
    "queued",
    "checking",
    "downloading metadata",
    "downloading",
    "finished",
    "seeding",
    "allocating",
    "checking fastresume",
]

layout = widgets.Layout(width="auto")
style = {"description_width": "initial"}
download_bars = [
    widgets.FloatSlider(
        step=0.01, disabled=True, layout=layout, style=style
    )
    for _ in downloads
]
display(*download_bars)

while downloads:
    next_shift = 0
    try:
        for index, download in enumerate(downloads[:]):
            bar = download_bars[index + next_shift]
            if not download.is_seed():
                s = download.status()

                bar.description = " ".join(
                    [
                        download.name(),
                        str(s.download_rate / 1000),
                        "kB/s",
                        state_str[s.state],
                    ]
                )
                bar.value = s.progress * 100
            else:
                next_shift -= 1
                ses.remove_torrent(download)
                downloads.remove(download)
                bar.close() # Seems to be not working in Colab (see https://github.com/googlecolab/colabtools/issues/726#issue-486731758)
                download_bars.remove(bar)
                print(download.name(), "complete")
        time.sleep(1)
    except:
        #print("Exception")
        continue
# Out:
# FloatSlider(value=0.0, disabled=True, layout=Layout(width='auto'), step=0.01, style=SliderStyle(description_wi…
# <ipython-input-4-900d1396c64f>:31: DeprecationWarning: is_seed() is deprecated
#   if not download.is_seed():
# <ipython-input-4-900d1396c64f>:36: DeprecationWarning: name() is deprecated
#   download.name(),
# <ipython-input-4-900d1396c64f>:49: DeprecationWarning: name() is deprecated
#   print(download.name(), "complete")
# UFC 305 UFC 305 Du Plessis vs Adesanya Main Event Only Feed Eng Int 17-08-24 Main Event Only Feed Eng Int 17-08-24[TGx] complete

# %%
import os
os.chdir("/content/drive/My Drive/Torrent")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-33eb819399cd> in <cell line: 2>()
#       1 import os
# ----> 2 os.chdir("/content/drive/My Drive/Torrent")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Torrent'

# %%
# !du -hs "[Anime Time] Code Geass Full Series [BD][Dual Audio][1080p][HEVC 10bit x265][AAC][Eng Sub]/Movie"
# Out:
# 1.8G	[Anime Time] Code Geass Full Series [BD][Dual Audio][1080p][HEVC 10bit x265][AAC][Eng Sub]/Movie

# %%
#!rm -rf "/content/drive/My Drive/Torrent/*"
# !rm -rf /content/United*
# !cp -r "/content/[Anime Time] Code Geass Full Series [BD][Dual Audio][1080p][HEVC 10bit x265][AAC][Eng Sub]/Movie" '/content/drive/My Drive/Torrent/'

# %%
# !cd "/content/drive/My Drive/Torrent/"

# %%
# !curl ipecho.net/plain
# Out:
# 35.202.155.222

# %%
# prompt: in the /content directory, check all the files and the sizes

# !find /content -type f -exec du -hs {} +
# Out:
# 4.0K	/content/.config/configurations/config_default
# 4.0K	/content/.config/.last_opt_in_prompt.yaml
# 4.0K	/content/.config/logs/2024.01.18/14.21.14.838196.log
# 4.0K	/content/.config/logs/2024.01.18/14.21.03.392855.log
# 4.0K	/content/.config/logs/2024.01.18/14.20.43.075617.log
# 4.0K	/content/.config/logs/2024.01.18/14.21.15.646902.log
# 40K	/content/.config/logs/2024.01.18/14.20.17.088067.log
# 12K	/content/.config/logs/2024.01.18/14.20.54.540679.log
# 4.0K	/content/.config/.last_survey_prompt.yaml
# 0	/content/.config/config_sentinel
# 4.0K	/content/.config/active_config
# 4.0K	/content/.config/.last_update_check.json
# 4.0K	/content/.config/gce
# 12K	/content/.config/default_configs.db
# 48K	/content/Dave.Chappelle.Whats.in.a.Name.2022.1080p.WEBRip.x265-RARBG/Subs/2_English.srt
# 4.0K	/content/Dave.Chappelle.Whats.in.a.Name.2022.1080p.WEBRip.x265-RARBG/RARBG_DO_NOT_MIRROR.exe
# ...
